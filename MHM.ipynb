# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !wget https://git.ufz.de/mhm/mhm/-/archive/develop/mhm-develop.tar.gz &> /dev/null
# Out:
# --2021-11-14 15:11:50--  https://git.ufz.de/mhm/mhm/-/archive/develop/mhm-develop.tar.gz
# Resolving git.ufz.de (git.ufz.de)... 141.65.7.38
# Connecting to git.ufz.de (git.ufz.de)|141.65.7.38|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘mhm-develop.tar.gz’
#
# mhm-develop.tar.gz      [         <=>        ]  61.41M  1.57MB/s    in 34s
#
# 2021-11-14 15:12:25 (1.81 MB/s) - ‘mhm-develop.tar.gz’ saved [64393592]

# %%
# !tar -zxvf mhm-develop.tar.gz &> /dev/null
# Out:
# mhm-develop/
# mhm-develop/.gitignore
# mhm-develop/.gitlab-ci.yml
# mhm-develop/CI-scripts/
# mhm-develop/CI-scripts/compile
# mhm-develop/CI-scripts/compile_MPI
# mhm-develop/CI-scripts/compile_MPI_debug
# mhm-develop/CI-scripts/compile_OpenMP
# mhm-develop/CI-scripts/compile_OpenMP_debug
# mhm-develop/CI-scripts/compile_conda
# mhm-develop/CI-scripts/compile_debug
# mhm-develop/CI-scripts/pre_check
# mhm-develop/CI-scripts/run_cmake_coverage.sh
# mhm-develop/CMakeCacheFiles/
# mhm-develop/CMakeCacheFiles/eve
# mhm-develop/CMakeCacheFiles/example
# mhm-develop/CMakeCacheFiles/specificSetup
# mhm-develop/CMakeLists.txt
# mhm-develop/LICENSE
# mhm-develop/README.md
# mhm-develop/check/
# mhm-develop/check/README.md
# mhm-develop/check/case_00/
# mhm-develop/check/case_00/mhm.nml
# mhm-develop/check/case_00/mhm_outputs.nml
# mhm-develop/check/case_00/mhm_parameter.nml
# mhm-develop/check/case_00/mrm_outputs.nml
# mhm-develop/check/case_00/output_save/
# ...

# %%
# !sudo apt-get install gfortran netcdf-bin libnetcdf-dev libnetcdff-dev cmake &> /dev/null
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# libnetcdf-dev is already the newest version (1:4.6.0-2build1).
# libnetcdf-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.2).
# gfortran is already the newest version (4:7.4.0-1ubuntu2.3).
# The following additional packages will be installed:
#   libnetcdff6
# Suggested packages:
#   netcdf-doc
# The following NEW packages will be installed:
#   libnetcdff-dev libnetcdff6 netcdf-bin
# 0 upgraded, 3 newly installed, 0 to remove and 37 not upgraded.
# Need to get 556 kB of archives.
# After this operation, 1,973 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdff6 amd64 4.4.4+ds-3 [92.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libnetcdff-dev amd64 4.4.4+ds-3 [275 kB]
# ...

# %%
cd /content/mhm-develop
# Out:
# /content/mhm-develop

# %%
# !mkdir xd

# %%
cd xd
# Out:
# /content/mhm-develop/xd

# %%
# !cmake  -DCMAKE_WITH_OpenMP:STRING=ON -DCMAKE_BUILD_TYPE=Release .. &> /dev/null

# %%
# !make &> /dev/null

# %%
# !cp ./mhm ..

# %%
cd ..
# Out:
# /content/mhm-develop

# %%
# !./mhm
# Out:
# ----------------------------------------------------------------------
#               mHM-UFZ
#
#     MULTISCALE HYDROLOGIC MODEL
#            Version: 5.11.3-dev0
#            Date:    2021-11-14
#
# Originally by L. Samaniego & R. Kumar
# ----------------------------------------------------------------------
#
# OpenMP used.
# MPI not used.
# Start at 14.11.2021 15:16:15.
# Working directory: /content/mhm-develop
# Using main file mhm_driver.f90 and namelists:
#      mhm.nml
#      mhm_parameter.nml
#      mhm_outputs.nml
#
# Run with OpenMP with          2 threads.
#
# Read namelist file: mhm.nml
# Read namelist file: mhm_parameter.nml
# Read namelist file: mhm_outputs.nml
#  INFO: Process (10, neutrons) is deactivated, so output will be suppressed.
#
# domain 1:
# resolution Hydrology (domain 1)     = 24000.
# resolution Routing (domain 1)       = 24000.
#
# Resolution of routing and hydrological modeling are equal!
#
# domain 2:
# resolution Hydrology (domain 2)     = 24000.
# ...

# %%
cd /content/gdrive/MyDrive/mhm/Konya/RUN_16100_ERA5
# Out:
# /content/gdrive/MyDrive/mhm/Konya/RUN_16100_ERA5

# %%
# !chmod +x mhm

# %%
# !./mhm
# Out:
# ----------------------------------------------------------------------
#               mHM-UFZ
#
#     MULTISCALE HYDROLOGIC MODEL
#            Version: 5.11.3-dev0
#            Date:    2021-11-14
#
# Originally by L. Samaniego & R. Kumar
# ----------------------------------------------------------------------
#
# OpenMP used.
# MPI not used.
# Start at 14.11.2021 16:57:46.
# Working directory: /content/gdrive/MyDrive/mhm/Konya/RUN_16100_ERA5
# Using main file mhm_driver.f90 and namelists:
#      mhm.nml
#      mhm_parameter.nml
#      mhm_outputs.nml
#
# Run with OpenMP with          2 threads.
#
# Read namelist file: mhm.nml
# Read namelist file: mhm_parameter.nml
# Read namelist file: mhm_outputs.nml
#  INFO: Process (10, neutrons) is deactivated, so output will be suppressed.
#
# domain 1:
# resolution Hydrology (domain 1)     = 0.31250E-01
# resolution Routing (domain 1)       = 0.31250E-01
#
# Resolution of routing and hydrological modeling are equal!
#
# ...
